# %%
# Anjali Rana
# 102017095
# 3CS5
# ML ASSIGNMENT 2

# %% [markdown]
# PART - 1

# %%
import pandas as pd

# %%
df1 = pd.read_csv('AWCustomers.csv')
df1.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
df1.shape
# Out:
# (18361, 24)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18361 entries, 0 to 18360
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            18361 non-null  int64
#  1   Title                 101 non-null    object
#  2   FirstName             18361 non-null  object
#  3   MiddleName            10572 non-null  object
#  4   LastName              18361 non-null  object
#  5   Suffix                3 non-null      object
#  6   AddressLine1          18361 non-null  object
#  7   AddressLine2          311 non-null    object
#  8   City                  18361 non-null  object
#  9   StateProvinceName     18361 non-null  object
#  10  CountryRegionName     18361 non-null  object
#  11  PostalCode            18361 non-null  object
#  12  PhoneNumber           18361 non-null  object
#  13  BirthDate             18361 non-null  object
#  14  Education             18361 non-null  object
# ...

# %%
df1.Gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df1.drop(columns=['CustomerID','Title','FirstName','MiddleName','LastName','Suffix','AddressLine1','AddressLine2','City','StateProvinceName','PostalCode','LastUpdated','PhoneNumber'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#   CountryRegionName   BirthDate        Education      Occupation Gender  \
# 0         Australia  1987-11-13        Bachelors        Clerical      M
# 1            Canada  1972-07-21  Partial College        Clerical      M
# 2     United States  1985-11-09        Bachelors        Clerical      F
# 3    United Kingdom  1977-10-18  Partial College  Skilled Manual      M
# 4           Germany  1975-02-05  Partial College  Skilled Manual      M
#
#   MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# 0             M              1                3                     0
# 1             M              1                2                     1
# 2             S              0                3                     0
# 3             M              1                2                     1
# 4             S              1                1                     0
#
#    TotalChildren  YearlyIncome
# 0              1         81916
# 1              2         81076
# ...

# %%
df1.describe()
# Out:
#        HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  TotalChildren  \
# count   18361.000000     18361.000000          18361.000000   18361.000000
# mean        0.610588         1.270301              0.338162       0.850389
# std         0.487630         0.913989              0.568957       0.927315
# min         0.000000         0.000000              0.000000       0.000000
# 25%         0.000000         1.000000              0.000000       0.000000
# 50%         1.000000         1.000000              0.000000       0.000000
# 75%         1.000000         2.000000              1.000000       2.000000
# max         1.000000         5.000000              3.000000       3.000000
#
#         YearlyIncome
# count   18361.000000
# mean    72754.779642
# std     30686.014313
# min     25435.000000
# 25%     53312.000000
# 50%     61851.000000
# 75%     87410.000000
# max    139115.000000

# %% [markdown]
# PART - 2

# %%
df1['Gender'].replace('M',1,inplace=True)
df1['Gender'].replace('F',0,inplace=True)

# %%
df1.Gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df1['MaritalStatus'].replace('M',1,inplace=True)
df1['MaritalStatus'].replace('S',0,inplace=True)

# %%
df1.head()
# Out:
#   CountryRegionName   BirthDate        Education      Occupation  Gender  \
# 0         Australia  1987-11-13        Bachelors        Clerical       1
# 1            Canada  1972-07-21  Partial College        Clerical       1
# 2     United States  1985-11-09        Bachelors        Clerical       0
# 3    United Kingdom  1977-10-18  Partial College  Skilled Manual       1
# 4           Germany  1975-02-05  Partial College  Skilled Manual       1
#
#    MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# 0              1              1                3                     0
# 1              1              1                2                     1
# 2              0              0                3                     0
# 3              1              1                2                     1
# 4              0              1                1                     0
#
#    TotalChildren  YearlyIncome
# 0              1         81916
# 1              2         81076
# ...

# %%
len(df1.CountryRegionName.unique())
# Out:
# 6

# %%
ohe_countries=pd.get_dummies(df1['CountryRegionName'],drop_first=True)
df1.drop(columns=['CountryRegionName'],axis=1,inplace=True)
df1=pd.concat([ohe_countries,df1],axis=1)

# %%
df1.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States   BirthDate  \
# 0       0       0        0               0              0  1987-11-13
# 1       1       0        0               0              0  1972-07-21
# 2       0       0        0               0              1  1985-11-09
# 3       0       0        0               1              0  1977-10-18
# 4       0       0        1               0              0  1975-02-05
#
#          Education      Occupation  Gender  MaritalStatus  HomeOwnerFlag  \
# 0        Bachelors        Clerical       1              1              1
# 1  Partial College        Clerical       1              1              1
# 2        Bachelors        Clerical       0              0              0
# 3  Partial College  Skilled Manual       1              1              1
# 4  Partial College  Skilled Manual       1              0              1
#
#    NumberCarsOwned  NumberChildrenAtHome  TotalChildren  YearlyIncome
# ...

# %%
df1['BirthDate']= pd.to_datetime(df1['BirthDate'])

import datetime
CURRENT_TIME = datetime.datetime.now()

def get_age(birth_date,today=CURRENT_TIME):
    y=today-birth_date
    return y.days//365

df1['Age']=df1['BirthDate'].apply(lambda x: get_age(x))

df1.drop(['BirthDate'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States        Education  \
# 0       0       0        0               0              0        Bachelors
# 1       1       0        0               0              0  Partial College
# 2       0       0        0               0              1        Bachelors
# 3       0       0        0               1              0  Partial College
# 4       0       0        1               0              0  Partial College
#
#        Occupation  Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0        Clerical       1              1              1                3
# 1        Clerical       1              1              1                2
# 2        Clerical       0              0              0                3
# 3  Skilled Manual       1              1              1                2
# 4  Skilled Manual       1              0              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  Age
# ...

# %%
len(df1.Education.unique())
# Out:
# 5

# %%
df1['Education'].value_counts()
# Out:
# Bachelors              5325
# Partial College        5024
# High School            3274
# Graduate Degree        3163
# Partial High School    1575
# Name: Education, dtype: int64

# %%
df1['Education']=df1['Education'].map({'Partial High School':1,'High School':2,'Partial College':3,'Bachelors':4,'Graduate Degree':5})

# %%
df1['Occupation']=df1['Occupation'].map({'Manual':1,'Skilled Manual':2,'Clerical':3,'Management':4,'Professional':5})

# %%
df1.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States  Education  \
# 0       0       0        0               0              0          4
# 1       1       0        0               0              0          3
# 2       0       0        0               0              1          4
# 3       0       0        0               1              0          3
# 4       0       0        1               0              0          3
#
#    Occupation  Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           3       1              1              1                3
# 1           3       1              1              1                2
# 2           3       0              0              0                3
# 3           2       1              1              1                2
# 4           2       1              0              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  Age
# 0                     0              1         81916   34
# ...

# %%
df1.isnull().sum()
# Out:
# Canada                  0
# France                  0
# Germany                 0
# United Kingdom          0
# United States           0
# Education               0
# Occupation              0
# Gender                  0
# MaritalStatus           0
# HomeOwnerFlag           0
# NumberCarsOwned         0
# NumberChildrenAtHome    0
# TotalChildren           0
# YearlyIncome            0
# Age                     0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df1[['YearlyIncome_scaled','Age_Scaled']] = scaler.fit_transform(df1[['YearlyIncome','Age']])

# %%
df1.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States  Education  \
# 0       0       0        0               0              0          4
# 1       1       0        0               0              0          3
# 2       0       0        0               0              1          4
# 3       0       0        0               1              0          3
# 4       0       0        1               0              0          3
#
#    Occupation  Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           3       1              1              1                3
# 1           3       1              1              1                2
# 2           3       0              0              0                3
# 3           2       1              1              1                2
# 4           2       1              0              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  Age  \
# 0                     0              1         81916   34
# ...

# %%
df1.drop(['YearlyIncome','Age'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Canada  France  Germany  United Kingdom  United States  Education  \
# 0       0       0        0               0              0          4
# 1       1       0        0               0              0          3
# 2       0       0        0               0              1          4
# 3       0       0        0               1              0          3
# 4       0       0        1               0              0          3
#
#    Occupation  Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0           3       1              1              1                3
# 1           3       1              1              1                2
# 2           3       0              0              0                3
# 3           2       1              1              1                2
# 4           2       1              0              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome_scaled  Age_Scaled
# ...

# %% [markdown]
# PART - 3

# %%
from scipy.spatial import distance

# %%
distance.cosine(df1['Education'].values,df1['YearlyIncome_scaled'].values)
# Out:
# 0.12448913241018533

# %%
distance.cosine(df1['Age_Scaled'].values,df1['YearlyIncome_scaled'].values)
# Out:
# 0.26995464877378605

# %%
distance.jaccard(df1['Education'].values,df1['YearlyIncome_scaled'].values)
# Out:
# 1.0

# %%
import matplotlib as plt
import seaborn as sns

# %%
plt.figure.Figure(figsize=(10,6))
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>
